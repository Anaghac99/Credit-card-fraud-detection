# %% [markdown]
# ### CREDIT CARD FRAUD DETECTION

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("creditcard.csv") #uploads the dataset

# %%
data.head() # show columns and rows of the dataset
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns = None # this will help to show all columns

# %%
data.head() #this shows first 5 rows of the dataset
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.tail() #shows last 5 rows of the dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
data.shape # shows how many rows and columns are there in the dataset
# Out:
# (284807, 31)

# %%
print("Number of columns: {}".format(data.shape[1]))#printing no.of columns and rows
print("Number of rows: {}".format(data.shape[0]))
# Out:
# Number of columns: 31
# Number of rows: 284807

# %%
data.info() #Gives information about how many columns are there ,what are there's data types, and whether there is any missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#here we can see that just 'class' has int datatype all other are float. 'class' is the value which we need to predict. Here this is a supervised machine learning problem beacause the target class is already given.

# %%
#from above itself we came to know that there is no null value. but if  there is null value ,we check this by following code:

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.hist(bins=30,figsize=(30,30))
# Out:
# array([[<Axes: title={'center': 'V1'}>, <Axes: title={'center': 'V2'}>,
#         <Axes: title={'center': 'V3'}>, <Axes: title={'center': 'V4'}>,
#         <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>],
#        [<Axes: title={'center': 'V11'}>, <Axes: title={'center': 'V12'}>,
#         <Axes: title={'center': 'V13'}>, <Axes: title={'center': 'V14'}>,
#         <Axes: title={'center': 'V15'}>],
#        [<Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>,
#         <Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>],
#        [<Axes: title={'center': 'V21'}>, <Axes: title={'center': 'V22'}>,
#         <Axes: title={'center': 'V23'}>, <Axes: title={'center': 'V24'}>,
#         <Axes: title={'center': 'V25'}>],
# ...

# %%
data.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.037460      -0.002430       0.025520      -0.004359
# std         1.952522       1.667260       1.507538       1.424323
# min       -56.407510     -72.715728     -48.325589      -5.683171
# 25%        -0.941105      -0.614040      -0.843168      -0.862847
# 50%        -0.059659       0.070249       0.200736      -0.035098
# 75%         1.294471       0.819067       1.048461       0.753943
# max         2.454930      22.057729       9.382558      16.875344
#
#                   V5             V6             V7             V8  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.010660      -0.014206       0.008586      -0.005698
# std         1.378117       1.313213       1.240348       1.191596
# min      -113.743307     -26.160506     -43.557242     -73.216718
# ...

# %%
#This is a unbalanced data,since it has only less no. of target class

# %%
#Since there are float points datasets and also negative numbers. first we need to convert  it in standard scalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']= sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data = data.drop(['Time'],axis =1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
#Next we need to check whether there is any duplicate value is there is not

# %%
data.duplicated().any()# check for duplicates
# Out:
# True

# %%
data = data.drop_duplicates() # removes the duplicates from the data

# %%
data.duplicated().any()
# Out:
# False

# %%
data.shape
# Out:
# (275663, 30)

# %%
# next we need to check whether the data is balance or unbalanced

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
#here we came to know that about 275190 are legitimate transaction and about 473 are fradulent transactions

# %%
 #next we need to plot this data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
sns.countplot(data['Class'])
plt.show()

# %%
# first we  will check without handleling unbalanced data how the machine learning model will work

# %%
# First we divde from datasets into dependent and independent features (ie, x and y)

# %%
x= data.drop(['Class'],axis=1)
y= data['Class']

# %%
# next we are dividing our dataset into train,test and split

# %%
from sklearn.model_selection import train_test_split

# %%
# next we pass our x data and y data in our train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(x,y,train_size=0.2,random_state=42)

# %%
# applying machine learning algorithmns

# %%
#for that first we need to import our machine learning algorithms

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score, precision_score,recall_score

# %%
#Now we apply Ml algorithmn and check the accuracy score

# %%
#Now we create a dictionary 'classifier'.Inside this classifier we initialise the which  ML algorithmns using here. here we using logistic regression, and decision tree classifier

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "Random Forest Clasifier": RandomForestClassifier()
}

for name,clf in classifier.items(): ##''in this dictionary , first gives the key the value.here 'name' is the key(which type of model it is for ex: logistic regression, decision tree classifier). and classifier is the instance of that
    print(f"\n==========={name}===========")
    clf.fit(x_train,y_train) #using this classifier to fit the data. if it is fit it would pass the x_train and y_train
    y_pred = clf.predict(x_test)#next we prdict the data based on the test data
    print(f"\n\nAccuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\nPrecision Score: {precision_score(y_test,y_pred)}")
    print(f"\nRecall Score: {recall_score(y_test,y_pred)}")
    print(f"\nF1 Score: {f1_score(y_test,y_pred)}")
# Out:
# ===========Logistic Regression===========
#
#
# Accuracy: 0.9990341493939627
#
# Precision Score: 0.8628318584070797
#
# Recall Score: 0.5172413793103449
#
# F1 Score: 0.6467661691542289
#
# ===========Decision Tree Classifier===========
#
#
# Accuracy: 0.9989842697852003
#
# Precision Score: 0.6808510638297872
#
# Recall Score: 0.7639257294429708
#
# F1 Score: 0.72
#
# ===========Random Forest Clasifier===========
#
#
# Accuracy: 0.9993560995959752
#
# Precision Score: 0.8706624605678234
#
# Recall Score: 0.7320954907161804
#
# F1 Score: 0.7953890489913544

# %%
# if the dataset is unbalanced we can only check accuracy score. if all of the values are almost equal then it means that the model is perfect.but here all the values are different. so we need to handle the unbalanced data.

# %%
#Next we handle the unbalanced data. there are two methods for it over sampling and under sampling

# %%
#First we apply the under sampling technique

# %%
legitimate = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
legitimate.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
legitimate_sample = legitimate.sample(n=473)

# %%
legitimate_sample.shape
# Out:
# (473, 30)

# %%
# to get a new data we add our both legitimate_sample and fraud

# %%
new_data =pd.concat([legitimate_sample,fraud],ignore_index=True)

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.186525  1.674830  1.636699  0.145109 -0.232905 -1.231766  0.613098
# 1 -0.675479 -0.103197 -1.636837  1.447317  2.690860 -1.469681  0.151692
# 2 -1.109498  0.496312 -0.261381  0.645003  1.361017 -0.584914 -0.091111
# 3  0.351849  0.957609 -0.401357  0.732850  0.881800 -0.991746  1.285371
# 4 -2.203363  0.713193  1.067871 -0.025410 -0.450905 -0.936419 -0.055856
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.204677  1.282749  0.223355  1.266569 -1.811094  2.590152  1.195773
# 1 -0.031838 -0.175857  0.201250  0.744763 -0.155953 -1.594018 -0.555423
# 2  0.574168 -1.120630 -1.008001  1.276303  0.361180  0.119278 -0.837970
# 3 -0.281990 -0.307179 -0.184876 -1.396822 -0.585908 -1.348876  0.655228
# 4  0.753595 -0.262424 -1.160732 -1.267352  0.099892 -0.739800  0.507423
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
new_data.shape
# Out:
# (946, 30)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
# the major problem of under sampling is that we lost lots of data

# %%
#Once again we divide our data into train,test and split . Before that we make it into dependent and independent features.

# %%
x= new_data.drop(['Class'],axis=1)
y= new_data['Class']

# %%
x_train, x_test, y_train, y_test =train_test_split(x,y,train_size=0.2,random_state=42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "Random Forest Clasifier": RandomForestClassifier()
}

for name,clf in classifier.items(): ##''in this dictionary , first gives the key the value.here 'name' is the key(which type of model it is for ex: logistic regression, decision tree classifier). and classifier is the instance of that
    print(f"\n==========={name}===========")
    clf.fit(x_train,y_train) #using this classifier to fit the data. if it is fit it would pass the x_train and y_train
    y_pred = clf.predict(x_test)#next we prdict the data based on the test data
    print(f"\n\nAccuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\nPrecision Score: {precision_score(y_test,y_pred)}")
    print(f"\nRecall Score: {recall_score(y_test,y_pred)}")
    print(f"\nF1 Score: {f1_score(y_test,y_pred)}")
# Out:
# ===========Logistic Regression===========
#
#
# Accuracy: 0.9194187582562747
#
# Precision Score: 0.9316939890710383
#
# Recall Score: 0.9045092838196287
#
# F1 Score: 0.917900403768506
#
# ===========Decision Tree Classifier===========
#
#
# Accuracy: 0.9075297225891678
#
# Precision Score: 0.9050131926121372
#
# Recall Score: 0.9098143236074271
#
# F1 Score: 0.9074074074074074
#
# ===========Random Forest Clasifier===========
#
#
# Accuracy: 0.9326287978863936
#
# Precision Score: 0.9794117647058823
#
# Recall Score: 0.883289124668435
#
# F1 Score: 0.9288702928870293

# %%
#After doing the under sampling , we got a better accuracy score, precision score , recall score and f1 score which are almost approximate than before.

# %%
# next we will try over sampling

# %%
#for that we divide our data into dependent and independent

# %%
x= data.drop(['Class'],axis=1)
y= data['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
#next we use smote, after that we can  fit and resample  not transform because we have only 473 data and we want it to resample it to x and y
x_res,y_res = SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
x_train, x_test, y_train, y_test =train_test_split(x_res,y_res,train_size=0.2,random_state=42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "Random Forest Clasifier": RandomForestClassifier()
}

for name,clf in classifier.items(): ##''in this dictionary , first gives the key the value.here 'name' is the key(which type of model it is for ex: logistic regression, decision tree classifier). and classifier is the instance of that
    print(f"\n==========={name}===========")
    clf.fit(x_train,y_train) #using this classifier to fit the data. if it is fit it would pass the x_train and y_train
    y_pred = clf.predict(x_test)#next we prdict the data based on the test data
    print(f"\n\nAccuracy: {accuracy_score(y_test,y_pred)}")
    print(f"\nPrecision Score: {precision_score(y_test,y_pred)}")
    print(f"\nRecall Score: {recall_score(y_test,y_pred)}")
    print(f"\nF1 Score: {f1_score(y_test,y_pred)}")
# Out:
# ===========Logistic Regression===========
#
#
# Accuracy: 0.944583742141793
#
# Precision Score: 0.9744367459663743
#
# Recall Score: 0.9131666651531525
#
# F1 Score: 0.9428073169130953
#
# ===========Decision Tree Classifier===========
#
#
# Accuracy: 0.9933046258948363
#
# Precision Score: 0.9914906899734
#
# Recall Score: 0.9951552411482124
#
# F1 Score: 0.9933195857599311
#
# ===========Random Forest Clasifier===========
#
#
# Accuracy: 0.9995525818525383
#
# Precision Score: 0.9994008306665759
#
# Recall Score: 0.9997048647372389
#
# F1 Score: 0.9995528245823904

# %%
#next we save decision tree classifier model

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
#for saving the model we use joblib

# %%
import joblib

# %%
#After importing joblib, we use joblib.dump and inside dump we give our model name dtc and  then give our model name 'credit_card_model.pkl'
joblib.dump(dtc, "credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
#After dumping the model we need to load the model

# %%
model = joblib.load("credit_crad_model.pkl")

# %%
#Now it's time to predict

# %%
pred = model.predict([[-1.35835406159823,-1.34016307473609,1.77320934263119,0.379779593034328,-0.503198133318193,1.80049938079263,0.791460956450422,0.247675786588991,-1.51465432260583,0.207642865216696,0.624501459424895,0.066083685268831,0.717292731410831,-0.165945922763554,2.34586494901581,-2.89008319444231,1.10996937869599,-0.121359313195888,-2.26185709530414,0.524979725224404,0.247998153469754,0.771679401917229,0.909412262347719,-0.689280956490685,-0.327641833735251,-0.139096571514147,-0.0553527940384261,-0.0597518405929204,378.66]])
# Out:
# C:\Users\anagh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pred[0]
# Out:
# 0

# %%
if pred[0] == 0:
    print("Normal Transaction")
else:
    print("Fraud  Transaction")
# Out:
# Normal Transaction
